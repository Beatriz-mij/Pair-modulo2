# %%
import pandas as pd

# %%
import mysql.connector
from mysql.connector import errorcode

# %%
try:
  cnx = mysql.connector.connect(user='root', password='AlumnaAdalab',
                              host='127.0.0.1',
                              database='information_schema')

except mysql.connector.Error as err:

  if err.errno == errorcode.ER_ACCESS_DENIED_ERROR:
    print("Something is wrong with your user name or password")
  
  elif err.errno == errorcode.ER_BAD_DB_ERROR:
    print("Database does not exist")
  
  else:
    print(err)

# %%
#1: cursor:
mycursor = cnx.cursor()

# %%
query0 = "USE information_schema"

# %%
query1 = ("""SELECT COLUMN_NAME 
                FROM COLUMNS 
                WHERE TABLE_NAME = 'customers' AND table_schema = 'northwind'""")

# %%
mycursor.execute(query0)

# %%
df1 = pd.read_sql_query(query1,cnx)
# Out:
# /var/folders/38/59xzc2ls53d5z9gzc2sfl76m0000gn/T/ipykernel_18215/3274585630.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df1 = pd.read_sql_query(query1,cnx)

# %%
df1.head(10)
# Out:
#     COLUMN_NAME
# 0    CustomerID
# 1   CompanyName
# 2   ContactName
# 3  ContactTitle
# 4       Address
# 5          City
# 6        Region
# 7    PostalCode
# 8       Country
# 9         Phone

# %%
query2 = ("""USE northwind""")
query3 = (""" SELECT *
                FROM `customers`
                WHERE `city` IN ('London', 'Seattle')""")

# %%
mycursor.execute(query2)

# %%
df3 = pd.read_sql_query(query3,cnx)
# Out:
# /var/folders/38/59xzc2ls53d5z9gzc2sfl76m0000gn/T/ipykernel_18215/3898771329.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df3 = pd.read_sql_query(query3,cnx)

# %%
df3_dataframe = pd.DataFrame(df3)
df3_dataframe
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 3      EASTC     Eastern Connection          Ann Devon           Sales Agent
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
# 6      WHITC   White Clover Markets     Karl Jablonski                 Owner
#
#                         Address     City Region PostalCode Country  \
# 0               120 Hanover Sq.   London   None    WA1 1DP      UK
# 1             Fauntleroy Circus   London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery   London   None    WX1 6LT      UK
# 3                35 King George   London   None    WX3 6FW      UK
# ...

# %%
#Muestra las 3 primeras filas del Dataframe y las 3 últimas.

df3_dataframe.head(3)
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 0      AROUT        Around the Horn       Thomas Hardy  Sales Representative
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
#
#                         Address    City Region PostalCode Country  \
# 0               120 Hanover Sq.  London   None    WA1 1DP      UK
# 1             Fauntleroy Circus  London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery  London   None    WX1 6LT      UK
#
#             Phone             Fax
# 0  (171) 555-7788  (171) 555-6750
# 1  (171) 555-1212            None
# 2  (171) 555-2282  (171) 555-9199

# %%
df3_dataframe.tail(3)
# Out:
#   CustomerID           CompanyName     ContactName     ContactTitle  \
# 4      NORTS           North/South  Simon Crowther  Sales Associate
# 5      SEVES    Seven Seas Imports      Hari Kumar    Sales Manager
# 6      WHITC  White Clover Markets  Karl Jablonski            Owner
#
#                         Address     City Region PostalCode Country  \
# 4  South House 300 Queensbridge   London   None    SW7 1RZ      UK
# 5               90 Wadhurst Rd.   London   None   OX15 4NB      UK
# 6   305 - 14th Ave. S. Suite 3B  Seattle     WA      98128     USA
#
#             Phone             Fax
# 4  (171) 555-7733  (171) 555-2530
# 5  (171) 555-1717  (171) 555-5646
# 6  (206) 555-4112  (206) 555-4115

# %%
#muestra 5 filas aleatorias
df3_dataframe.sample(5) #por defecto nos devuelve 1
# Out:
#   CustomerID            CompanyName        ContactName          ContactTitle  \
# 4      NORTS            North/South     Simon Crowther       Sales Associate
# 6      WHITC   White Clover Markets     Karl Jablonski                 Owner
# 1      BSBEV          B's Beverages  Victoria Ashworth  Sales Representative
# 2      CONSH  Consolidated Holdings    Elizabeth Brown  Sales Representative
# 5      SEVES     Seven Seas Imports         Hari Kumar         Sales Manager
#
#                         Address     City Region PostalCode Country  \
# 4  South House 300 Queensbridge   London   None    SW7 1RZ      UK
# 6   305 - 14th Ave. S. Suite 3B  Seattle     WA      98128     USA
# 1             Fauntleroy Circus   London   None    EC2 5NT      UK
# 2  Berkeley Gardens 12  Brewery   London   None    WX1 6LT      UK
# 5               90 Wadhurst Rd.   London   None   OX15 4NB      UK
#
#             Phone             Fax
# 4  (171) 555-7733  (171) 555-2530
# ...

# %%
#¿Hay nulos en el Dataframe? El resultado debe verse para cada una de las columnas.

#respuesta nuestra= OJO los "null" aparecen como "none" en el DataFrame.
df3_dataframe.isnull()
# Out:
#    CustomerID  CompanyName  ContactName  ContactTitle  Address   City  Region  \
# 0       False        False        False         False    False  False    True
# 1       False        False        False         False    False  False    True
# 2       False        False        False         False    False  False    True
# 3       False        False        False         False    False  False    True
# 4       False        False        False         False    False  False    True
# 5       False        False        False         False    False  False    True
# 6       False        False        False         False    False  False   False
#
#    PostalCode  Country  Phone    Fax
# 0       False    False  False  False
# 1       False    False  False   True
# 2       False    False  False  False
# 3       False    False  False  False
# 4       False    False  False  False
# 5       False    False  False  False
# 6       False    False  False  False

# %%
df3_dataframe.isnull().sum()
# Out:
# CustomerID      0
# CompanyName     0
# ContactName     0
# ContactTitle    0
# Address         0
# City            0
# Region          6
# PostalCode      0
# Country         0
# Phone           0
# Fax             1
# dtype: int64

# %%
#Mostrar los principales estadísticos.
df3_dataframe.describe()
# Out:
#        CustomerID      CompanyName   ContactName          ContactTitle  \
# count           7                7             7                     7
# unique          7                7             7                     5
# top         AROUT  Around the Horn  Thomas Hardy  Sales Representative
# freq            1                1             1                     3
#
#                 Address    City Region PostalCode Country           Phone  \
# count                 7       7      1          7       7               7
# unique                7       2      1          7       2               7
# top     120 Hanover Sq.  London     WA    WA1 1DP      UK  (171) 555-7788
# freq                  1       6      1          1       6               1
#
#                    Fax
# count                6
# unique               6
# top     (171) 555-6750
# freq                 1

# %%
df3_dataframe.describe(include = 'object')
# Out:
#        CustomerID      CompanyName   ContactName          ContactTitle  \
# count           7                7             7                     7
# unique          7                7             7                     5
# top         AROUT  Around the Horn  Thomas Hardy  Sales Representative
# freq            1                1             1                     3
#
#                 Address    City Region PostalCode Country           Phone  \
# count                 7       7      1          7       7               7
# unique                7       2      1          7       2               7
# top     120 Hanover Sq.  London     WA    WA1 1DP      UK  (171) 555-7788
# freq                  1       6      1          1       6               1
#
#                    Fax
# count                6
# unique               6
# top     (171) 555-6750
# freq                 1

# %%
#Mostrar el nombre de las columnas del Dataframe.
df3_dataframe.columns
# Out:
# Index(['CustomerID', 'CompanyName', 'ContactName', 'ContactTitle', 'Address',
#        'City', 'Region', 'PostalCode', 'Country', 'Phone', 'Fax'],
#       dtype='object')

# %%
cnx.close()
