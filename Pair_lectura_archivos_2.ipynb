# %%
import pandas as pd
import json

# %%
# Hacer las importaciones necesarias para abrir un archivo de tipo csv en Pandas:

df = pd.read_csv("videogames.csv")

# %%
# Abrir el archivo, creando un dataframe. Aseguraros de que no incluye la columna "Unnamed: 0":

df.head()
# Out:
#    Unnamed: 0                        name  \
# 0           0                  Spider-Man
# 1           1      Red Dead Redemption II
# 2           2          Grand Theft Auto V
# 3           3                  God of War
# 4           4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# ...

# %%
df_2 = pd.read_csv("videogames.csv", index_col=0)

# %%
df_2
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %%
df_2.head()
# Out:
#                          name  \
# 0                  Spider-Man
# 1      Red Dead Redemption II
# 2          Grand Theft Auto V
# 3                  God of War
# 4  Uncharted 4: A Thief's End
#
#                                                  url    year certificate  \
# 0  https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1  https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2  https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3  https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# 4  https://www.imdb.com/title/tt3334704/?ref_=adv...  2016.0           T
#
#    rating   votes                                               plot  Action  \
# 0     9.2  20,759  When a new villain threatens New York City, Pe...    True
# 1     9.7  35,703  Amidst the decline of the Wild West at the tur...    True
# 2     9.5  59,986  Three very different criminals team up for a s...    True
# ...

# %%
# Guardar el dataframe en formato Excel y después crear un dataframe con el Excel. ¿El dataframe es similar al que teníais antes?:

df_2.to_excel("videogames.xlsx")

# %%
df_3 = pd.read_excel("videogames.xlsx")

# %%
# Crear una carpeta llamada Files y guardar el mismo archivo en esa carpeta en formato csv:

df_2.to_csv("files/videogames.csv")

# %%
# Copia el archivo personal.json en la carpeta Files:

pj = ("files/cp personal.json")

# %%
pwd # te dice dónde estás ahora en tu jupyter
# Out:
# 'c:\\Users\\bmija\\Desktop\\PROMO 49\\ADALAB\\MODULO 2 EXTRAER DATOS Y SQL'

# %%
with open("files/personal_copy.json", "w") as fichero: # Aquí cambio esa "r", ahora la "w" hace referencia a escritura
    json.dump("personal", fichero)

# %%
# Abre el fichero json (con el json.load(f)) y haz las modificaciones necesarias para que tenga formato de tabla (Para esto necesitas normalizar los datos con el pd.json_normalize):

# %%
with open("files/personal_copy.json", "r") as fichero: 
    personal_copy = json.load(fichero)

# %%
personal_copy
# Out:
# 'personal'

# %%
# Guardar el json modificado y abrirlo en Pandas.¿Cómo queda ahora?

# Guardar el JSON modificado:
with open ("files/personal_copy.json", "w") as fichero:
    json.dump(personal_copy, fichero)

# %%
df = pd.read_json("files/personal_copy.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19448\511600736.py in ?()
# ----> 1 df = pd.read_json("files/personal_copy.json")
#
# c:\Users\bmija\anaconda3\Lib\site-packages\pandas\io\json\_json.py in ?(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, precise_float, date_unit, encoding, encoding_errors, lines, chunksize, compression, nrows, storage_options, dtype_backend, engine)
#     811
#     812     if chunksize:
#     813         return json_reader
#     814     else:
# --> 815         return json_reader.read()
#
# c:\Users\bmija\anaconda3\Lib\site-packages\pandas\io\json\_json.py in ?(self)
#    1021                         data = ensure_str(self.data)
#    1022                         data_lines = data.split("\n")
# ...
